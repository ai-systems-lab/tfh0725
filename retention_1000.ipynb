# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
fpath = '10NIIIS4/retention_test_1000/2025-07-22 15-53-10_+retention.csv'

# %%
df = pd.read_csv(fpath, delimiter=';')
plt.plot(df.adc, 'o', markersize=1)

# %%
df.res = df.res.apply(lambda x: float(x.replace(',','.')))
plt.plot(df.res, 'o', markersize=1)
